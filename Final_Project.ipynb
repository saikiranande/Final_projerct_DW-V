# %%
import pandas as pd
import numpy as np
url = 'https://raw.githubusercontent.com/SR1608/Datasets/main/covid-data.csv'

# %% [markdown]
# # 1. Import the dataset using Pandas from above mentioned url.

# %%
df = pd.read_csv(url,index_col = 0)
df.head()
# Out:
#          continent     location      date  total_cases  new_cases  \
# iso_code
# AFG           Asia  Afghanistan  31/12/19          NaN        0.0
# AFG           Asia  Afghanistan  01/01/20          NaN        0.0
# AFG           Asia  Afghanistan  02/01/20          NaN        0.0
# AFG           Asia  Afghanistan  03/01/20          NaN        0.0
# AFG           Asia  Afghanistan  04/01/20          NaN        0.0
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# AFG                      NaN           NaN         0.0                  NaN
# AFG                      NaN           NaN         0.0                  NaN
# AFG                      NaN           NaN         0.0                  NaN
# AFG                      NaN           NaN         0.0                  NaN
# AFG                      NaN           NaN         0.0                  NaN
#
#           total_cases_per_million  ...  gdp_per_capita  extreme_poverty  \
# ...

# %% [markdown]
# # 2. High Level Data Understanding:
# #### a. Find no. of rows & columns in the dataset
# #### b. Data types of columns.
# #### c. Info & describe of data in dataframe.

# %%
df.shape
# Out:
# (57394, 48)

# %%
df.dtypes
# Out:
# continent                              object
# location                               object
# date                                   object
# total_cases                           float64
# new_cases                             float64
# new_cases_smoothed                    float64
# total_deaths                          float64
# new_deaths                            float64
# new_deaths_smoothed                   float64
# total_cases_per_million               float64
# new_cases_per_million                 float64
# new_cases_smoothed_per_million        float64
# total_deaths_per_million              float64
# new_deaths_per_million                float64
# new_deaths_smoothed_per_million       float64
# reproduction_rate                     float64
# icu_patients                          float64
# icu_patients_per_million              float64
# hosp_patients                         float64
# hosp_patients_per_million             float64
# ...

# %%
df.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 57394 entries, AFG to nan
# Data columns (total 48 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   continent                           56748 non-null  object
#  1   location                            57394 non-null  object
#  2   date                                57394 non-null  object
#  3   total_cases                         53758 non-null  float64
#  4   new_cases                           56465 non-null  float64
#  5   new_cases_smoothed                  55652 non-null  float64
#  6   total_deaths                        44368 non-null  float64
#  7   new_deaths                          56465 non-null  float64
#  8   new_deaths_smoothed                 55652 non-null  float64
#  9   total_cases_per_million             53471 non-null  float64
#  10  new_cases_per_million               56401 non-null  float64
# ...

# %% [markdown]
# # 3. Low Level Data Understanding :
# #### a. Find count of unique values in location column.
# #### b. Find which continent has maximum frequency using values counts.
# #### c. Find maximum & mean value in 'total_cases'.
# #### d. Find 25%,50% & 75% quartile value in 'total_deaths'.
# #### e. Find which continent has maximum 'human_development_index'.
# #### f. Find which continent has minimum 'gdp_per_capita'.

# %%
print(df['location'].nunique)
# Out:
# <bound method IndexOpsMixin.nunique of iso_code
# AFG      Afghanistan
# AFG      Afghanistan
# AFG      Afghanistan
# AFG      Afghanistan
# AFG      Afghanistan
#            ...
# NaN    International
# NaN    International
# NaN    International
# NaN    International
# NaN    International
# Name: location, Length: 57394, dtype: object>

# %%
print(df['continent'].value_counts().max())
# Out:
# 14828

# %%
print('max of total_cases : ',df['total_cases'].max())
print('mean of total_cases : ',df['total_cases'].mean())
# Out:
# max of total_cases :  55154651.0
# mean of total_cases :  167797.3688753302

# %%
print('Quartile of 25% : ',df['total_deaths'].quantile([0.25]) ,'\n')
print('Quartile of 50% : ',df['total_deaths'].quantile([0.5]),'\n')
print('Quartile of 75% : ',df['total_deaths'].quantile([0.75]), ' \n')
# Out:
# Quartile of 25% :  0.25    13.0
# Name: total_deaths, dtype: float64
#
# Quartile of 50% :  0.5    84.0
# Name: total_deaths, dtype: float64
#
# Quartile of 75% :  0.75    727.0
# Name: total_deaths, dtype: float64

# %%
print('Max of human_development_index : ', df['human_development_index'].max())
# Out:
# Max of human_development_index :  0.953

# %%
print('Min of gdp_per_capita : ', df['gdp_per_capita'].min())
# Out:
# Min of gdp_per_capita :  661.24

# %% [markdown]
# # 4. Filter the dataframe with only this columns['continent','location','date','total_cases','total_deaths','gdp_per_capita','human_development_index'] and update the data frame.

# %%
df.filter(['continent','location','date','total_cases','total_deaths','gdp_per_capita','human_development_index'])
# Out:
#          continent       location      date  total_cases  total_deaths  \
# iso_code
# AFG           Asia    Afghanistan  31/12/19          NaN           NaN
# AFG           Asia    Afghanistan  01/01/20          NaN           NaN
# AFG           Asia    Afghanistan  02/01/20          NaN           NaN
# AFG           Asia    Afghanistan  03/01/20          NaN           NaN
# AFG           Asia    Afghanistan  04/01/20          NaN           NaN
# ...            ...            ...       ...          ...           ...
# NaN            NaN  International  13/11/20        696.0           7.0
# NaN            NaN  International  14/11/20        696.0           7.0
# NaN            NaN  International  15/11/20        696.0           7.0
# NaN            NaN  International  16/11/20        696.0           7.0
# NaN            NaN  International  17/11/20        696.0           7.0
#
#           gdp_per_capita  human_development_index
# iso_code
# ...

# %% [markdown]
# # 5. Data Cleaning
# #### a. Remove all duplicates observations
# #### b. Find missing values in all columns
# #### c. Remove all observations where continent column value is missing
# #### Tip : using subset parameter in dropna
# #### d. Fill all missing values with 0

# %%
df.duplicated(keep = False)
# Out:
# iso_code
# AFG    False
# AFG    False
# AFG    False
# AFG    False
# AFG    False
#        ...
# NaN    False
# NaN    False
# NaN    False
# NaN    False
# NaN    False
# Length: 57394, dtype: bool

# %%
df.drop_duplicates(keep = False)
# Out:
#          continent       location      date  total_cases  new_cases  \
# iso_code
# AFG           Asia    Afghanistan  31/12/19          NaN        0.0
# AFG           Asia    Afghanistan  01/01/20          NaN        0.0
# AFG           Asia    Afghanistan  02/01/20          NaN        0.0
# AFG           Asia    Afghanistan  03/01/20          NaN        0.0
# AFG           Asia    Afghanistan  04/01/20          NaN        0.0
# ...            ...            ...       ...          ...        ...
# NaN            NaN  International  13/11/20        696.0        NaN
# NaN            NaN  International  14/11/20        696.0        NaN
# NaN            NaN  International  15/11/20        696.0        NaN
# NaN            NaN  International  16/11/20        696.0        NaN
# NaN            NaN  International  17/11/20        696.0        NaN
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# ...

# %%
df.isnull()
# Out:
#           continent  location   date  total_cases  new_cases  \
# iso_code
# AFG           False     False  False         True      False
# AFG           False     False  False         True      False
# AFG           False     False  False         True      False
# AFG           False     False  False         True      False
# AFG           False     False  False         True      False
# ...             ...       ...    ...          ...        ...
# NaN            True     False  False        False       True
# NaN            True     False  False        False       True
# NaN            True     False  False        False       True
# NaN            True     False  False        False       True
# NaN            True     False  False        False       True
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# AFG                     True          True       False                 True
# ...

# %%
df.dropna(subset = ['continent'], how = 'all')
# Out:
#          continent     location      date  total_cases  new_cases  \
# iso_code
# AFG           Asia  Afghanistan  31/12/19          NaN        0.0
# AFG           Asia  Afghanistan  01/01/20          NaN        0.0
# AFG           Asia  Afghanistan  02/01/20          NaN        0.0
# AFG           Asia  Afghanistan  03/01/20          NaN        0.0
# AFG           Asia  Afghanistan  04/01/20          NaN        0.0
# ...            ...          ...       ...          ...        ...
# ZWE         Africa     Zimbabwe  13/11/20       8696.0       29.0
# ZWE         Africa     Zimbabwe  14/11/20       8765.0       69.0
# ZWE         Africa     Zimbabwe  15/11/20       8786.0       21.0
# ZWE         Africa     Zimbabwe  16/11/20       8786.0        0.0
# ZWE         Africa     Zimbabwe  17/11/20       8897.0      111.0
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# ...

# %%
df.fillna(0)
# Out:
#          continent       location      date  total_cases  new_cases  \
# iso_code
# AFG           Asia    Afghanistan  31/12/19          0.0        0.0
# AFG           Asia    Afghanistan  01/01/20          0.0        0.0
# AFG           Asia    Afghanistan  02/01/20          0.0        0.0
# AFG           Asia    Afghanistan  03/01/20          0.0        0.0
# AFG           Asia    Afghanistan  04/01/20          0.0        0.0
# ...            ...            ...       ...          ...        ...
# NaN              0  International  13/11/20        696.0        0.0
# NaN              0  International  14/11/20        696.0        0.0
# NaN              0  International  15/11/20        696.0        0.0
# NaN              0  International  16/11/20        696.0        0.0
# NaN              0  International  17/11/20        696.0        0.0
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# ...

# %% [markdown]
# # 6. Date time format :
# #### a. Convert date column in datetime format using pandas.to_datetime
# #### b. Create new column month after extracting month data from date column.

# %%
df.dtypes['date']
# Out:
# dtype('O')

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df.dtypes['date']
# Out:
# dtype('<M8[ns]')

# %%
df['month'] = df['date'].dt.month

# %%
df.dtypes
# Out:
# continent                                     object
# location                                      object
# date                                  datetime64[ns]
# total_cases                                  float64
# new_cases                                    float64
# new_cases_smoothed                           float64
# total_deaths                                 float64
# new_deaths                                   float64
# new_deaths_smoothed                          float64
# total_cases_per_million                      float64
# new_cases_per_million                        float64
# new_cases_smoothed_per_million               float64
# total_deaths_per_million                     float64
# new_deaths_per_million                       float64
# new_deaths_smoothed_per_million              float64
# reproduction_rate                            float64
# icu_patients                                 float64
# icu_patients_per_million                     float64
# ...

# %% [markdown]
# # 7. Data Aggregation:
# #### a. Find max value in all columns using groupby function on 'continent'column
# #### Tip: use reset_index() after applying groupby
# #### b. Store the result in a new dataframe named 'df_groupby'.
# #### (Use df_groupby dataframe for all further analysis)

# %%
df_1 = df.groupby(['continent']).max().reset_index()
print(df_1)
# Out:
#        continent                      location       date  total_cases  \
# 0         Africa                      Zimbabwe 2020-12-11     752269.0
# 1           Asia                         Yemen 2020-12-11    8874290.0
# 2         Europe                       Vatican 2020-12-11    1991233.0
# 3  North America  United States Virgin Islands 2020-12-11   11205486.0
# 4        Oceania             Wallis and Futuna 2020-12-11      27750.0
# 5  South America                     Venezuela 2020-12-11    5876464.0
#
#    new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0    13944.0           12583.714       20314.0       572.0
# 1    97894.0           93198.571      130519.0      2003.0
# 2    86852.0           54868.571       52147.0      2004.0
# 3   184813.0          156419.143      247220.0      4928.0
# 4     1384.0             551.714         907.0        59.0
# 5    69074.0           46393.000      166014.0      3935.0
#
# ...

# %%
df_groupby = pd.DataFrame(df_1)

# %%
x = df_groupby.head()

# %% [markdown]
# # 8. Feature Engineering :
# #### a. Create a new feature 'total_deaths_to_total_cases' by ratio of'total_deaths' column to 'total_cases'

# %%
df['total_deaths_to_total_cases'] = df['total_deaths'] / df['total_cases']
print(df['total_deaths_to_total_cases'])
# Out:
# iso_code
# AFG         NaN
# AFG         NaN
# AFG         NaN
# AFG         NaN
# AFG         NaN
#          ...
# NaN    0.010057
# NaN    0.010057
# NaN    0.010057
# NaN    0.010057
# NaN    0.010057
# Name: total_deaths_to_total_cases, Length: 57394, dtype: float64

# %% [markdown]
# # 9. Data Visualization :
# #### a. Perform Univariate analysis on 'gdp_per_capita' column by plottinghistogram using seaborn dist plot.
# #### b. Plot a scatter plot of 'total_cases' & 'gdp_per_capita'
# #### c. Plot Pairplot on df_groupby dataset.
# #### d. Plot a bar plot of 'continent' column with 'total_cases' .
# #### Tip : using kind='bar' in seaborn catplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.hist(df['gdp_per_capita'], range = (0,100000), bins = 10)
plt.show()

# %%
sns.displot(df['gdp_per_capita'], kind = 'hist')

# %%
sns.scatterplot(data = df, x = 'total_cases', y = 'gdp_per_capita', hue = 'new_cases')
# Out:
# <AxesSubplot:xlabel='total_cases', ylabel='gdp_per_capita'>

# %%
sns.pairplot(data = x, hue = 'continent')

# %%
sns.catplot(data = df_groupby, x = 'continent' , y = 'total_cases' , kind = 'bar')

# %% [markdown]
# # 10.Save the df_groupby dataframe in your local drive using pandas.to_csv function .

# %%
df_groupby.to_csv('df_groupby.csv')
